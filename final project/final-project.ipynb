# %% [markdown]
# ## PROG8245 Final Project: Applying NLP to Major Tasks

# %% [markdown]
# #### Group 8
# - Jun He(8903073)
# - Li, Zheming()
# - Li, Haoyang()
# #### **Notice:Due on 9th of December,2024**

# %% [markdown]
# ### Topic:  XXXXXX

# %% [markdown]
# ### Dataset Introduction:

# %% [markdown]
# ### Preparation: packages, classes, functions etc.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, ne_chunk
from nltk.tree import Tree
import string
import math
from collections import defaultdict

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\xll12\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\xll12\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Data Collection and Preparation
class DataCollectionPreprocessing:
    def __init__(self):
        self.raw_data = None
        self.processed_data = None
    
    def collect_data(self, data_source='kaggle'):
        """
        Collect data from various sources
        
        Possible data sources:
        - Kaggle datasets
        - Web scraping (Selenium, BeautifulSoup)
        - APIs (Reddit PRAW, Amazon Product API)
        - Hugging Face datasets
        """
        # Data collection methods (placeholder)
        if data_source == 'kaggle':
            # Example: Download dataset from Kaggle
            pass
        elif data_source == 'web_scraping':
            # Implement web scraping logic
            pass
        elif data_source == 'api':
            # Implement API data collection
            pass
    
    def annotate_dataset(self, annotation_method='huggingface'):
        """
        Annotate dataset with sentiment labels
        
        Methods:
        - Hugging Face pre-trained models
        - Custom labeling functions
        - Manual annotation
        """
        # Annotation logic
        if annotation_method == 'huggingface':
            # Use Hugging Face inference API for sentiment annotation
            pass
    
    def preprocess_text(self, text):
        """
        Perform text preprocessing
        
        Steps:
        - Lowercase conversion
        - Remove special characters
        - Remove stopwords
        - Stemming/Lemmatization
        - Handle hashtags, emojis, slang
        """
        # Text preprocessing implementation
        # 1. Lowercase
        text = text.lower()
        
        # 2. Remove special characters
        # Add regex or string method to clean text
        
        # 3. Remove stopwords
        # Use NLTK or spaCy stopwords
        
        # 4. Stemming/Lemmatization
        # Use NLTK or spaCy
        
        return text
    
    def clean_dataset(self):
        """
        Clean and prepare dataset
        
        - Remove irrelevant columns
        - Handle missing values
        - Apply text preprocessing
        """
        # Data cleaning logic
        pass

# %%
# Feature Extraction
class FeatureExtraction:
    def __init__(self):
        self.feature_methods = []
    
    def bag_of_words(self, data):
        """
        Bag of Words feature extraction
        """
        # Implement Bag of Words
        pass
    
    def tf_idf(self, data):
        """
        TF-IDF feature extraction
        """
        # Implement TF-IDF vectorization
        pass
    
    def word_embeddings(self, method='word2vec'):
        """
        Word Embedding techniques
        
        Methods:
        - Word2Vec
        - GloVe
        - FastText
        """
        # Implement word embedding logic
        pass
    
    def contextual_embeddings(self, method='bert'):
        """
        Contextual Embedding techniques
        
        Methods:
        - BERT
        - GPT
        """
        # Implement contextual embedding logic
        pass

# %%
# Model Training and Evaluation
class ModelTraining:
    def __init__(self):
        self.models = []
    
    def split_dataset(self, X, y, test_size=0.2):
        """
        Split dataset into training and testing sets
        """
        # Use sklearn train_test_split
        pass
    
    def train_models(self, features, labels):
        """
        Train multiple models:
        - Naive Bayes
        - SVM
        - Neural Networks
        """
        # Model training logic
        pass
    
    def evaluate_models(self):
        """
        Evaluate model performance
        
        Metrics:
        - Accuracy
        - Precision
        - Recall
        - F1-Score
        """
        # Model evaluation logic
        pass

# %%
# Visualization and Interpretation
class ResultVisualization:
    def visualize_results(self, model_performances):
        """
        Visualize model and feature extraction performances
        
        Types of visualizations:
        - Bar charts
        - Confusion matrices
        - Performance comparison plots
        """
        # Visualization implementation
        pass
    
    def generate_report(self):
        """
        Generate comprehensive project report
        
        Sections:
        - Methodology
        - Results
        - Challenges
        - Insights
        """
        # Report generation logic
        pass

# %%
# Initialize classes
data_collector = DataCollectionPreprocessing()
feature_extractor = FeatureExtraction()
model_trainer = ModelTraining()
visualizer = ResultVisualization()

# %% [markdown]
# ### Part 1: Data Collection
# - Collect a dataset of product reviews. This can be obtained from APIs like Amazon
# Product API, Yelp API, or a public dataset such as the "Sentiment140" dataset or any
# other product review dataset available on platforms like Kaggle. (10)
#     * Facebook provides an API but it is complicated. You can find it here.
#     * You can make use of reddit API (PRAW) here.
#     * Or you can make use of a Web Scraping techniques like Selenium, or
# BeautifulSoap libraries.
# - Annotate the dataset with labels of positive, negative or neutral sentiment, based on
# collected data. (10)
#     * You can use pretrained models from (https://huggingface.co/inference-api) to
# annotate your dataset.

# %%
# 1. Collect and preprocess data
data_collector.collect_data()
data_collector.annotate_dataset()
processed_data = data_collector.clean_dataset()

# %% [markdown]
# ### Part 2: Preprocessing
# - Perform necessary text preprocessing steps such as tokenization, stop-word removal,
# stemming/lemmatization, and lowercasing. (10)
# - Remove any irrelevant columns, handle missing values, and clean text data by removing
# special characters, stopwords, and performing stemming/lemmatization.
# - Handle specific challenges of used text like hashtags, emojis, and slang. (10)

# %%
    # 2. Extract features using multiple techniques
bow_features = feature_extractor.bag_of_words(processed_data)
tfidf_features = feature_extractor.tf_idf(processed_data)
word_emb_features = feature_extractor.word_embeddings()

# %% [markdown]
# ### Part 3: Feature Extraction and Model Comparison

# %%
# 3. Train and evaluate models
labels = []
model_trainer.split_dataset(bow_features, labels)
model_trainer.train_models()
model_performances = model_trainer.evaluate_models()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 labels = []
#       3 model_trainer.split_dataset(bow_features, labels)
# ----> 4 model_trainer.train_models()
#       5 model_performances = model_trainer.evaluate_models()
#
# TypeError: ModelTraining.train_models() missing 2 required positional arguments: 'features' and 'labels'

# %% [markdown]
# #### 3-1 Explore different feature
# Explore different feature representation methods such as bag-of-words, TF-IDF, word
# embeddings (e.g., Word2Vec or GloVe), or contextual embeddings (e.g., BERT or GPT).
# Experiment with 3 different feature extraction techniques to capture meaningful
# representations of social media text where the 3 techniques should be of different
# word embedding categories.

# %% [markdown]
# #### 3-2 Model Building
# - Choose a suitable machine learning algorithm (e.g., Naive Bayes, SVM, or neural
# networks) or deep learning model
# - Split the dataset into training and testing sets.
# - Train the selected model using the training data, evaluate and record its
# performance on the training and testing data.

# %%
#  SVM

# %% [markdown]
# #### 3-3 Interpretation of results
# - Visualize your results
# - Compare different feature representation
# - Reach a conclusion on which is the best Embedding technique to use for your model

# %% [markdown]
# ### Part 4 Conclusion
# - Create a comprehensive report documenting the **project's methodology, results, and
# findings**.
# - Prepare a presentation to showcase the **NLP project, discuss challenges faced, and
# highlight insights** gained from the project. Including a live demonstration test cases
# that will be tested during the presentation which will be handled In Class.
